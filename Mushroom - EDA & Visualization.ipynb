# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('mushrooms.csv')

# %% [markdown]
# # Data Cleaning

# %%
df.sample(10)
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 1677     e         f           s         n       f    n               f
# 6093     p         f           y         n       f    f               f
# 1468     e         f           f         g       f    n               f
# 1491     p         f           s         w       t    p               f
# 4374     p         x           s         w       t    f               f
# 6621     p         x           s         n       f    f               f
# 6387     p         x           y         e       f    f               f
# 5145     p         x           y         n       f    f               f
# 998      e         b           s         w       t    l               f
# 7850     p         k           y         n       f    f               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 1677            w         b          h  ...                        f
# 6093            c         n          b  ...                        k
# 1468            w         b          h  ...                        s
# 1491            c         n          p  ...                        s
# 4374            c         b          w  ...                        f
# 6621            c         n          b  ...                        s
# 6387            c         n          b  ...                        s
# 5145            c         n          b  ...                        k
# 998             c         b          w  ...                        s
# 7850            c         n          b  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 1677                      w                      w         p          w
# 6093                      p                      p         p          w
# 1468                      w                      w         p          w
# 1491                      w                      w         p          w
# 4374                      w                      w         p          w
# 6621                      p                      w         p          w
# 6387                      w                      p         p          w
# 5145                      p                      p         p          w
# 998                       w                      w         p          w
# 7850                      p                      w         p          w
#
#      ring-number ring-type spore-print-color population habitat
# 1677           o         e                 n          s       g
# 6093           o         e                 w          v       l
# 1468           o         e                 k          a       g
# 1491           o         p                 n          s       u
# 4374           o         p                 h          s       u
# 6621           o         e                 w          v       d
# 6387           o         e                 w          v       p
# 5145           o         e                 w          v       l
# 998            o         p                 n          n       m
# 7850           o         e                 w          v       p
#
# [10 rows x 23 columns]

# %%
df.head(10)
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
# 5     e         x           y         y       t    a               f
# 6     e         b           s         w       t    a               f
# 7     e         b           y         w       t    l               f
# 8     p         x           y         w       t    p               f
# 9     e         b           s         y       t    a               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
# 5            c         b          n  ...                        s
# 6            c         b          g  ...                        s
# 7            c         b          n  ...                        s
# 8            c         n          p  ...                        s
# 9            c         b          g  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
# 5                      w                      w         p          w
# 6                      w                      w         p          w
# 7                      w                      w         p          w
# 8                      w                      w         p          w
# 9                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
# 5           o         p                 k          n       g
# 6           o         p                 k          n       m
# 7           o         p                 n          s       m
# 8           o         p                 k          v       g
# 9           o         p                 k          s       m
#
# [10 rows x 23 columns]

# %%
df.shape
# Out:
# (8124, 23)

# %%
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
# Unique values in columns

for column in df.columns:
    print(f"{column} : {df[column].unique()}")
# Out:
# class : ['p' 'e']
# cap-shape : ['x' 'b' 's' 'f' 'k' 'c']
# cap-surface : ['s' 'y' 'f' 'g']
# cap-color : ['n' 'y' 'w' 'g' 'e' 'p' 'b' 'u' 'c' 'r']
# bruises : ['t' 'f']
# odor : ['p' 'a' 'l' 'n' 'f' 'c' 'y' 's' 'm']
# gill-attachment : ['f' 'a']
# gill-spacing : ['c' 'w']
# gill-size : ['n' 'b']
# gill-color : ['k' 'n' 'g' 'p' 'w' 'h' 'u' 'e' 'b' 'r' 'y' 'o']
# stalk-shape : ['e' 't']
# stalk-root : ['e' 'c' 'b' 'r' '?']
# stalk-surface-above-ring : ['s' 'f' 'k' 'y']
# stalk-surface-below-ring : ['s' 'f' 'y' 'k']
# stalk-color-above-ring : ['w' 'g' 'p' 'n' 'b' 'e' 'o' 'c' 'y']
# stalk-color-below-ring : ['w' 'p' 'g' 'b' 'n' 'e' 'y' 'o' 'c']
# veil-type : ['p']
# veil-color : ['w' 'n' 'o' 'y']
# ring-number : ['o' 't' 'n']
# ring-type : ['p' 'e' 'l' 'f' 'n']
# spore-print-color : ['k' 'n' 'u' 'h' 'w' 'r' 'o' 'y' 'b']
# population : ['s' 'n' 'a' 'v' 'y' 'c']
# habitat : ['u' 'g' 'm' 'd' 'p' 'w' 'l']

# %%
mapped_df = df.copy()
feature_name_mappings = {
    "class":{'e':'edible','p':'poisonous'},
    "cap-shape": {'b':"bell","c":"conical","x":"convex","f":"flat", "k":"knobbed","s":"sunken"},
    'cap-surface': {'f':"fibrous","g":"grooves","y":"scaly","s":"smooth"},
    "cap-color": {'n':"brown",'b':'buff','c':'cinnamon','g':'gray','r':"green",'p':'pink','u':'purple','e':'red',
                  'w':'white','y':'yellow'},
    "bruises":{'t': 'bruises', 'f': 'no'},
    "odor":{'a': 'almond', 'l': 'anise', 'c': 'creosote', 'y': 'fishy', 'f': 'foul', 'm': 'musty', 'n': 'none', 
            'p': 'pungent', 's': 'spicy'},
    "gill-attachment":{'a': 'attached', 'd': 'descending', 'f': 'free', 'n': 'notched'},
    "gill-spacing":{'c': 'close', 'w': 'crowded', 'd': 'distant'},
    "gill-size":{'b': 'broad', 'n': 'narrow'},
    "gill-color":{'k': 'black', 'n': 'brown', 'b': 'buff', 'h': 'chocolate', 'g': 'gray', 'r': ' green', 'o': 'orange', 
                  'p': 'pink', 'u': 'purple', 'e': 'red', 'w': 'white', 'y': 'yellow'},
    "stalk-shape":{'e': 'enlarging', 't': 'tapering'},
    "stalk-root":{'b': 'bulbous', 'c': 'club', 'u': 'cup', 'e': 'equal', 'z': 'rhizomorphs', 'r': 'rooted',
                  '?': 'missing'},
    "stalk-surface-above-ring":{'f': 'fibrous', 'y': 'scaly', 'k': 'silky', 's': 'smooth'},
    "stalk-surface-below-ring":{'f': 'fibrous', 'y': 'scaly', 'k': 'silky', 's': 'smooth'},
    "stalk-color-above-ring":{'n': 'brown', 'b': 'buff', 'c': 'cinnamon', 'g': 'gray', 'o': 'orange', 'p': 'pink', 
                              'e': 'red', 'w': 'white', 'y': 'yellow'},
    "stalk-color-below-ring":{'n': 'brown', 'b': 'buff', 'c': 'cinnamon', 'g': 'gray', 'o': 'orange', 'p': 'pink',
                              'e': 'red', 'w': 'white', 'y': 'yellow'},
    "veil-type":{'p': 'partial', 'u': 'universal'},
    "veil-color":{'n': 'brown', 'o': 'orange', 'w': 'white', 'y': 'yellow'},
    "ring-number":{'n': 'none', 'o': 'one', 't': 'two'},
    "ring-type":{'c': 'cobwebby', 'e': 'evanescent', 'f': 'flaring', 'l': 'large', 'n': 'none', 'p': 'pendant',
                 's': 'sheathing', 'z': 'zone'},
    "spore-print-color":{'k': 'black', 'n': 'brown', 'b': 'buff', 'h': 'chocolate', 'r': 'green', 'o': 'orange',
                         'u': 'purple', 'w': 'white', 'y': 'yellow'},
    "population":{'a': 'abundant', 'c': 'clustered', 'n': 'numerous', 's': 'scattered', 'v': 'several', 'y': 'solitary'},
    "habitat":{'g': 'grasses', 'l': 'leaves', 'm': 'meadows', 'p': 'paths', 'u': 'urban', 'w': 'waste', 'd': 'woods'}
}
for column in mapped_df.columns:
    mapping_dict = feature_name_mappings[column]
    for index in range(len(mapped_df[column])):
        mapped_df[column][index] = mapping_dict[mapped_df[column][index]]

# %%
mapped_df.sample(10)
# Out:
#           class cap-shape cap-surface cap-color  bruises      odor  \
# 5376  poisonous      bell       scaly      pink  bruises      none
# 1472  poisonous      flat      smooth     white  bruises   pungent
# 5158  poisonous      flat       scaly    yellow       no      foul
# 4326     edible    convex       scaly     green       no      none
# 4695  poisonous      flat     fibrous    yellow       no      foul
# 6387  poisonous    convex       scaly       red       no      foul
# 4264  poisonous    convex     fibrous    yellow       no      foul
# 3978  poisonous    convex      smooth     white       no  creosote
# 1985     edible    convex     fibrous      gray  bruises      none
# 2517     edible    convex     fibrous       red  bruises      none
#
#      gill-attachment gill-spacing gill-size gill-color  ...  \
# 5376            free        close     broad      green  ...
# 1472            free        close    narrow      brown  ...
# 5158            free        close     broad  chocolate  ...
# 4326            free        close    narrow       pink  ...
# 4695            free        close     broad  chocolate  ...
# 6387            free        close    narrow       buff  ...
# 4264            free        close     broad       gray  ...
# 3978            free        close    narrow     purple  ...
# 1985            free        close     broad      brown  ...
# 2517            free        close     broad      white  ...
#
#      stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 5376                   smooth                  white                  white
# 1472                   smooth                  white                  white
# 5158                    silky                   pink                  brown
# 4326                  fibrous                  white                  white
# 4695                    silky                  brown                   pink
# 6387                   smooth                  white                   pink
# 4264                    silky                  brown                  brown
# 3978                   smooth                  white                  white
# 1985                   smooth                   gray                  white
# 2517                   smooth                   gray                   pink
#
#      veil-type veil-color ring-number   ring-type spore-print-color  \
# 5376   partial      white         two     pendant             green
# 1472   partial      white         one     pendant             black
# 5158   partial      white         one       large         chocolate
# 4326   partial      white         one     flaring         chocolate
# 4695   partial      white         one       large         chocolate
# 6387   partial      white         one  evanescent             white
# 4264   partial      white         one       large         chocolate
# 3978   partial      white         one     pendant             black
# 1985   partial      white         one     pendant             black
# 2517   partial      white         one     pendant             black
#
#      population  habitat
# 5376    several  meadows
# 1472    several    urban
# 5158   solitary    paths
# 4326    several    woods
# 4695    several    paths
# 6387    several    paths
# 4264   solitary  grasses
# 3978    several    woods
# 1985   solitary    woods
# 2517   solitary    woods
#
# [10 rows x 23 columns]

# %% [markdown]
# # EDA and Visualization

# %%
features = ['cap-shape', 'cap-surface', 'cap-color', 'veil-color', 'odor',
       'ring-type', 'spore-print-color', 'stalk-color-above-ring', 'gill-color',
       'stalk-color-below-ring']

# %%
plt.figure(figsize = (18,40))
for i in enumerate(features):
    plt.subplot(6, 3, i[0]+1)
    sns.countplot(i[1], hue = 'class',palette = 'hls',data = mapped_df)
    plt.xticks(rotation = 45)

plt.show()

# %%
plt.figure(figsize = [3,3])
sns.countplot(df['class'] ,palette = 'bright', alpha = 0.8)
plt.show()

# %% [markdown]
# ##### As we have almost equal number of p and e values, we dont need to oversample our data
